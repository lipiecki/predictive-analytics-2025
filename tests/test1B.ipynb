# %% [markdown]
# ## Test 1

# %% [markdown]
# ## Task 1
# Load the `task1.csv` dataset, use the first 600 timesteps as training window and rest for testing. Fit Holt Winters models with seasonality of (a) 7 days, (b) 28 days and (c) an AR model with lags 1 and 7 as regressors (include an intercept/bias). Compare models based on MAE and RMSE on the test set.

# %% [markdown]
# ## Task 2
#
# Load the `task2.csv` dataset, find the best linear regression model to predict `Sales` that uses **at most 2 regressors**. Select the optimal model based on the **MAE** on the **test** set. Use the last `XYZ` data points as the test set, and all the previous ones as the training set.
#
# `XYZ` are the last three digits of your student ID number.

# %% [markdown]
# ## Task 3
# Load the `task3.csv` dataset:
# 1) Transform the original time series $y_t$ into the series of logarithmic returns $r_t$. Generate a series of the cumulative sum of logarithmic returns: $s_t = \sum_{i=0}^{t} r_i$ (using `for` loop)
# 2) Calculate the p-value of the ADF test for the original series $y_t$, its logarithmic returns $r_t$ and the cumulative sum $s_t$
# 3) Fit an AR(1) model to the cumulative sum and compute the lag-1 autocorrelation of model residuals
