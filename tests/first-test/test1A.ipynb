# %% [markdown]
# # Test 1

# %% [markdown]
# ## Task 1
# Load the `task1.csv` dataset, use the first 600 timesteps as training window and rest for testing. Compare Naive, simple ETS and AR(1) models based on MAE and RMSE (in the ETS model estimate two parameters - alpha and the initial forecast/level).

# %% [markdown]
# ## Task 2
# Load the `task2.csv` dataset, find the best single predictor for `Sales` based on the leave one out cross validation scheme. Include intercept/bias in the models.

# %% [markdown]
# ## Task 3
# Load the `task3.csv` dataset, fit an AR(1) model to the entire time series. Test the stationarity of the original data and the residuals of the AR(1) model. Use the ADF test and compute the lag-1 autocorrelation for original data and the residuals.
