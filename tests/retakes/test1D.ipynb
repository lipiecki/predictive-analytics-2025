# %% [markdown]
# ## Test 1

# %% [markdown]
# ## Task 1
# Load the `task1.csv` dataset, use the first 600 timesteps as training window and rest for testing. Find the best seasonality for the Holt Winters model (on a grid of $\{2, 3, 4, 5, 6, 7\}$ days) based on the MSE on the test set. Compare against ETS model.

# %% [markdown]
# ## Task 2
#
# Load the `task2.csv` dataset, use leave-one-out cross-validation to find the best linear regression model to predict `Sales`, based on RMSE.

# %% [markdown]
# ## Task 3
# Load the `task3.csv` dataset:
# 1) Transform the original time series $y_t$ into the series of logarithmic returns $r_t$. Generate a series of the cumulative sum of logarithmic returns: $s_t = \sum_{i=0}^{t} r_i$ (using `for` loop)
# 2) Fit a simple AR(1) model to the cumulative sum $s_t$, print the estimated parameters.
# 3) Calculate the p-value of the ADF test for the residuals from the ETS model and for the cumulative sum series $s_t$. Compute the autocorrelation of the first 10 lags for both series (residuals and cumulative sum).
