# %% [markdown]
# ## Test 1

# %% [markdown]
# ## Task 1
# Load the `task1.csv` dataset, use the first 300 timesteps as training window and the rest for testing. Compare the simple ETS model with Holt-Winters (set seasonality to 7 days) and AR model with 1-day and 7-day lags (include the intercept).

# %% [markdown]
# ## Task 2
#
# Load the `task2.csv` dataset, use the first 1000 data points as the training set and the rest as the test set. Using Akaike Information Criterion select the best linear regression model to predict `Sales`. Report the RMSE on the test set for the selcted model and the model using all regressor variables.

# %% [markdown]
# ## Task 3
# Load the `task3.csv` dataset:
# 1) Transform the original time series $y_t$ into the series of logarithmic returns $r_t$. Generate a series of the cumulative sum of logarithmic returns: $s_t = \sum_{i=0}^{t} r_i$ (using `for` loop)
# 2) Fit a simple ETS model to the cumulative sum $s_t$, print the estimated parameters.
# 3) Calculate the p-value of the ADF test for the residuals from the ETS model and for the cumulative sum series $s_t$. Compute the autocorrelation of the first 10 lags for both series (residuals and cumulative sum).
