# %% [markdown]
# ## Test 1

# %% [markdown]
# ## Task 1
# Load the `task1.csv` dataset, use the first 600 timesteps as training window and rest for testing. Find the best seasonality for the Holt Winters model (on a grid of $\{7, 8, 9, ..., 26, 27, 28\}$ days) based on the MSE on the test set. Compare against the Naive forecasts.

# %% [markdown]
# ## Task 2
#
# Load the `task2.csv` dataset, find the best linear regression model to predict `Sales` that uses **at most 2 regressors**. Select the optimal model based on the **MAE** on the **test** set. Use the first `10XY` data points as the training set, and all the rest as the test set.
#
# `XY` are the last two digits of your student ID number.

# %% [markdown]
# ## Task 3
# Load the `task3.csv` dataset:
# 1) Transform the original time series $y_t$ into the series of logarithmic returns $r_t$. Generate a series of the cumulative sum of logarithmic returns: $s_t = \sum_{i=0}^{t} r_i$ (using `for` loop)
# 2) Fit a simple ETS model model to the cumulative sum $s_t$ (in the ETS model estimate two parameters - alpha and the initial forecast/level), print the estimated parameters.
# 3) Calculate the p-value of the ADF test for the residuals from the ETS model and for the cumulative sum series $s_t$. Compute the autocorrelation of the first 10 lags for both series (residuals and cumulative sum).
